# %%
import pandas as pd
import numpy as np
import quandl
import math, datetime
from sklearn import preprocessing, model_selection, svm # Since cross_validation is deprecated
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from matplotlib import style
import pickle

style.use('ggplot')

# %%
df = quandl.get("WIKI/GOOGL")
df.head()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19  100.01  104.06   95.96  100.335  44659000.0          0.0
# 2004-08-20  101.01  109.08  100.50  108.310  22834300.0          0.0
# 2004-08-23  110.76  113.48  109.05  109.400  18256100.0          0.0
# 2004-08-24  111.24  111.60  103.57  104.870  15247300.0          0.0
# 2004-08-25  104.76  108.00  103.88  106.000   9188600.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2004-08-19          1.0  50.159839  52.191109  48.128568   50.322842
# 2004-08-20          1.0  50.661387  54.708881  50.405597   54.322689
# 2004-08-23          1.0  55.551482  56.915693  54.693835   54.869377
# 2004-08-24          1.0  55.792225  55.972783  51.945350   52.597363
# 2004-08-25          1.0  52.542193  54.167209  52.100830   53.164113
#
#             Adj. Volume
# Date
# 2004-08-19   44659000.0
# 2004-08-20   22834300.0
# 2004-08-23   18256100.0
# 2004-08-24   15247300.0
# 2004-08-25    9188600.0

# %%
df = df[['Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume']]
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close']) / df['Adj. Close'] * 100.0
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0

df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]

df.head()
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume
# Date
# 2004-08-19   50.322842  3.712563    0.324968   44659000.0
# 2004-08-20   54.322689  0.710922    7.227007   22834300.0
# 2004-08-23   54.869377  3.729433   -1.227880   18256100.0
# 2004-08-24   52.597363  6.417469   -5.726357   15247300.0
# 2004-08-25   53.164113  1.886792    1.183658    9188600.0

# %%
forecast_col = "Adj. Close"
df.fillna(-99999, inplace=True)

# %%
# Predict 10% of data frame
forecast_out = int(math.ceil(0.01*len(df)))
df['label'] = df[forecast_col].shift(-forecast_out)
df.head()
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume      label
# Date
# 2004-08-19   50.322842  3.712563    0.324968   44659000.0  69.078238
# 2004-08-20   54.322689  0.710922    7.227007   22834300.0  67.839414
# 2004-08-23   54.869377  3.729433   -1.227880   18256100.0  68.912727
# 2004-08-24   52.597363  6.417469   -5.726357   15247300.0  70.668146
# 2004-08-25   53.164113  1.886792    1.183658    9188600.0  71.219849

# %%
df.tail()
# Out:
#             Adj. Close    HL_PCT  PCT_change  Adj. Volume  label
# Date
# 2018-03-21     1094.00  1.343693    0.130884    1990515.0    NaN
# 2018-03-22     1053.15  2.921711   -2.487014    3418154.0    NaN
# 2018-03-23     1026.55  3.918952   -2.360729    2413517.0    NaN
# 2018-03-26     1054.09  0.491419    0.332191    3272409.0    NaN
# 2018-03-27     1006.94  5.720301   -5.353887    2940957.0    NaN

# %%
X = np.array(df.drop(['label'],1))
X = preprocessing.scale(X)
X = X[:-forecast_out]
X_lately = X[-forecast_out:]
df.dropna(inplace=True)
y = np.array(df['label'])

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2)

# %%
# clf = LinearRegression()
# # clf = svm.SVR(kernel='poly')
# clf.fit(X_train, y_train)

# with open('linearregression.pickle','wb') as f:
#     pickle.dump(clf,f)
    
pickle_in = open('linearregression.pickle','rb')
clf = pickle.load(pickle_in)

accuracy = clf.score(X_test, y_test)
print(accuracy)
# Out:
# 0.9774138019124813

# %%
forecast_set = clf.predict(X_lately)
print(forecast_set, accuracy, forecast_out)
# Out:
# [1078.36819754 1093.03887828 1107.0264077  1101.5769304  1095.06495923
#  1092.44556504 1090.87042425 1087.82271959 1081.62770916 1077.25763747
#  1074.96148671 1094.61729901 1113.02513639 1117.40691183 1132.37173879
#  1136.36977854 1134.96273295 1132.5169059  1134.28544783 1152.81706874
#  1151.81783213 1161.93540794 1158.47461184 1166.3080079  1186.70899748
#  1199.02205095 1193.2055887  1205.2414358  1210.79860792 1208.85860758
#  1199.61058276 1205.17621844 1203.85272068 1139.29609214 1085.99903554] 0.9774138019124813 35

# %%
df['Forecast'] = np.nan
last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
one_day = 86400
next_unix = last_unix + one_day

# %%
for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    df.loc[next_date] = [np.nan for _ in range(len(df.columns) -1)] + [i]

# %%
df['Adj. Close'].plot()
df['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
